# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data - Preprocessing

# %%
games= pd.read_csv('/content/games.csv')
games_details=pd.read_csv('/content/games_details.csv')
players=pd.read_csv('/content/players.csv')
ranking= pd.read_csv('/content/ranking.csv')
teams=pd.read_csv('/content/teams.csv')
# Out:
# <ipython-input-2-56fed8acbbe0>:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_details=pd.read_csv('/content/games_details.csv')

# %%
print(games.shape,games_details.shape, players.shape, ranking.shape,teams.shape)
# Out:
# (26552, 20) (668628, 29) (7228, 4) (210342, 13) (30, 14)

# %%
games.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'GAME_ID', 'GAMES_STATUS', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'PTS_home', 'FG_PCT_home', 'FT_PCT_home',
#        'FG3_PCT_home', 'AST_home', 'REB_home', 'PTS_away', 'FG_PCT_away',
#        'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away',
#        'HOME_TEAM_WINS'],
#       dtype='object')

# %%
games_details.columns
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'PLAYER_ID',
#        'PLAYER_NAME', 'NICKNAME', 'START_POSITION', 'COMMENT', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS',
#        'PLUS_MINUS'],
#       dtype='object')

# %%
players.columns
# Out:
# Index(['PLAYER_NAME', 'TEAM_ID', 'PLAYER_ID', 'SEASON'], dtype='object')

# %%
ranking.columns
# Out:
# Index(['TEAM_ID', 'LEAGUE_ID', 'SEASON_ID', 'STANDINGSDATE', 'CONFERENCE',
#        'TEAM', 'G', 'W', 'L', 'W_PCT', 'HOME_RECORD', 'ROAD_RECORD',
#        'RETURNTOPLAY'],
#       dtype='object')

# %%
teams.columns
# Out:
# Index(['LEAGUE_ID', 'TEAM_ID', 'MIN_YEAR', 'MAX_YEAR', 'ABBREVIATION',
#        'NICKNAME', 'YEARFOUNDED', 'CITY', 'ARENA', 'ARENACAPACITY', 'OWNER',
#        'GENERALMANAGER', 'HEADCOACH', 'DLEAGUEAFFILIATION'],
#       dtype='object')

# %% [markdown]
# Checking null values

# %%
print(games.isna().sum())
# Out:
# Unnamed: 0         0
# Date               0
# GAME_ID            0
# GAMES_STATUS       0
# HOME_TEAM_ID       0
# VISITOR_TEAM_ID    0
# SEASON             0
# PTS_home           0
# FG_PCT_home        0
# FT_PCT_home        0
# FG3_PCT_home       0
# AST_home           0
# REB_home           0
# PTS_away           0
# FG_PCT_away        0
# FT_PCT_away        0
# FG3_PCT_away       0
# AST_away           0
# REB_away           0
# HOME_TEAM_WINS     0
# dtype: int64

# %%
games_details.isna().sum()
# Out:
# GAME_ID                   0
# TEAM_ID                   0
# TEAM_ABBREVIATION         0
# TEAM_CITY                 0
# PLAYER_ID                 0
# PLAYER_NAME               0
# NICKNAME             615591
# START_POSITION       412863
# COMMENT              558939
# MIN                  109690
# FGM                  109690
# FGA                  109690
# FG_PCT               109690
# FG3M                 109690
# FG3A                 109690
# FG3_PCT              109690
# FTM                  109690
# FTA                  109690
# FT_PCT               109690
# OREB                 109690
# DREB                 109690
# REB                  109690
# AST                  109690
# STL                  109690
# BLK                  109690
# TO                   109690
# PF                   109690
# PTS                  109690
# PLUS_MINUS           133351
# dtype: int64

# %%
players.isna().sum()
# Out:
# PLAYER_NAME    0
# TEAM_ID        0
# PLAYER_ID      0
# SEASON         0
# dtype: int64

# %%
ranking.isna().sum()
# Out:
# TEAM_ID               0
# LEAGUE_ID             0
# SEASON_ID             0
# STANDINGSDATE         0
# CONFERENCE            0
# TEAM                  0
# G                     0
# W                     0
# L                     0
# W_PCT                 0
# HOME_RECORD           0
# ROAD_RECORD           0
# RETURNTOPLAY     206352
# dtype: int64

# %%
teams.isna().sum()
# Out:
# LEAGUE_ID             0
# TEAM_ID               0
# MIN_YEAR              0
# MAX_YEAR              0
# ABBREVIATION          0
# NICKNAME              0
# YEARFOUNDED           0
# CITY                  0
# ARENA                 0
# ARENACAPACITY         4
# OWNER                 0
# GENERALMANAGER        0
# HEADCOACH             0
# DLEAGUEAFFILIATION    0
# dtype: int64

# %% [markdown]
# # GRAPH 01

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7228 entries, 0 to 7227
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PLAYER_NAME  7228 non-null   object
#  1   TEAM_ID      7228 non-null   int64
#  2   PLAYER_ID    7228 non-null   int64
#  3   SEASON       7228 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 226.0+ KB

# %%
players.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
players['PLAYER_NAME'].nunique()
# Out:
# 1749

# %%
teams.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
teams['NICKNAME'].nunique()
# Out:
# 30

# %%
ranking.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G  \
# 0  1610612743          0      22022    2022-12-22       West       Denver  30
# 1  1610612763          0      22022    2022-12-22       West      Memphis  30
# 2  1610612740          0      22022    2022-12-22       West  New Orleans  31
# 3  1610612756          0      22022    2022-12-22       West      Phoenix  32
# 4  1610612746          0      22022    2022-12-22       West  LA Clippers  33
#
#     W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  19  11  0.633        10-3         9-8           NaN
# 1  19  11  0.633        13-2         6-9           NaN
# 2  19  12  0.613        13-4         6-8           NaN
# 3  19  13  0.594        14-4         5-9           NaN
# 4  19  14  0.576        11-7         8-7           NaN

# %%
ranking['SEASON_ID'].unique()
# Out:
# array([22022, 12022, 22021, 12021, 22020, 12020, 22019, 12019, 22013,
#        12013, 22012, 12012, 22011, 12011, 22010, 12010, 22009, 12009,
#        22008, 12008, 22007, 12007, 22006, 12006, 22005, 12005, 22004,
#        12004, 22003, 12003, 22002, 22018, 12018, 22017, 12017, 22016,
#        12016, 22015, 12015, 22014, 12014])

# %%
# Extracting unique team IDs and their associated names from the original data

unique_teams = ranking[['TEAM_ID', 'TEAM']].drop_duplicates()

# %%
# Grouping the data by 'TEAM_ID' and aggregating the other columns
grouped_data1 = teams.groupby('TEAM_ID').agg({
    'NICKNAME':'first'
})

# %%
# Grouping the data by 'TEAM_ID' and aggregating the other columns
grouped_data = ranking.groupby('TEAM_ID').agg({
    'G': 'sum',  # Summing up games played
    'W': 'sum',  # Summing up wins
    'L': 'sum',  # Summing up losses
    'W_PCT': 'mean',  # Average win percentage
    'TEAM':'first'
})

# Sorting the grouped data based on the highest number of games played
grouped_data_sorted_by_games = grouped_data.sort_values(by='G', ascending=False)
result_df = pd.merge(grouped_data_sorted_by_games, grouped_data1, on='TEAM_ID', how='left')
# Display the resulting dataframe
result_df.head()
# Out:
#                  G       W       L     W_PCT      TEAM       NICKNAME
# TEAM_ID
# 1610612753  399990  177841  222149  0.447834   Orlando          Magic
# 1610612742  399370  234851  164519  0.568303    Dallas      Mavericks
# 1610612762  399314  216938  182376  0.540365      Utah           Jazz
# 1610612757  399227  203198  196029  0.502117  Portland  Trail Blazers
# 1610612756  398962  204032  194930  0.508756   Phoenix           Suns

# %%
# Concatenate 'TEAM' and 'NICKNAME' columns and store the result in a new column 'Team_Nickname'
result_df['Team_Nickname'] = result_df['TEAM'] + ' ' + result_df['NICKNAME']
result_df.head()
# Out:
#                  G       W       L     W_PCT      TEAM       NICKNAME  \
# TEAM_ID
# 1610612753  399990  177841  222149  0.447834   Orlando          Magic
# 1610612742  399370  234851  164519  0.568303    Dallas      Mavericks
# 1610612762  399314  216938  182376  0.540365      Utah           Jazz
# 1610612757  399227  203198  196029  0.502117  Portland  Trail Blazers
# 1610612756  398962  204032  194930  0.508756   Phoenix           Suns
#
#                      Team_Nickname
# TEAM_ID
# 1610612753           Orlando Magic
# 1610612742        Dallas Mavericks
# 1610612762               Utah Jazz
# 1610612757  Portland Trail Blazers
# 1610612756            Phoenix Suns

# %%
# Dropping the 'TEAM' and 'NICKNAME' columns
result_df = result_df.drop(['TEAM', 'NICKNAME'], axis=1)

# Display the updated dataframe without the dropped columns
result_df.head()
# Out:
#                  G       W       L     W_PCT           Team_Nickname
# TEAM_ID
# 1610612753  399990  177841  222149  0.447834           Orlando Magic
# 1610612742  399370  234851  164519  0.568303        Dallas Mavericks
# 1610612762  399314  216938  182376  0.540365               Utah Jazz
# 1610612757  399227  203198  196029  0.502117  Portland Trail Blazers
# 1610612756  398962  204032  194930  0.508756            Phoenix Suns

# %%
import matplotlib.pyplot as plt

# Assuming result_df is already defined and has the columns 'W', 'L', and 'Team_Nickname'

# Creating the subplots for the pie charts, adjusted for 6 teams
fig, axes = plt.subplots(1, 5, figsize=(20, 4))  # Adjusted layout for 6 pie charts
axes = axes.flatten()  # Flattening the axes array for easy iteration
plt.suptitle("Top 5 Teams with the Highest Number of Games Played", fontsize=16, x=0.4)

legend_labels = ['Wins', 'Losses']

for i, (idx, row) in enumerate(result_df.iterrows()):
    # Check if the index is within the range of axes
    if i >= len(axes):
        break  # Break the loop if i exceeds the length of axes

    # Data for pie chart
    labels = 'Wins', 'Losses'
    sizes = [row['W'], row['L']]
    team_name = row['Team_Nickname']

    # Plotting the pie chart
    wedges, texts, autotexts = axes[i].pie(sizes, autopct='%1.1f%%', startangle=140, colors=['#8fbc8f', '#3cb371'])
    axes[i].set_title("")  # Clear the default title

    # Arrange title in center
    axes[i].pie([1], colors=['w'], radius=0.4)  # Create a white circle at the center
    for autotext in autotexts:
        autotext.set_fontsize(12)  # Set the fontsize for percentage labels
    axes[i].set_xlabel(team_name, fontsize=14, ha='center')

# Create a common legend outside the subplots
fig.legend(legend_labels, loc='upper right', bbox_to_anchor=(0.86, 0.86), fontsize=10)

# Ensure the loop doesn't exceed the axes array size
for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to accommodate the main title and legend
plt.show()

# %%
players.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
games_details.shape
# Out:
# (668628, 29)

# %%
games_details.isna().sum()
# Out:
# GAME_ID                   0
# TEAM_ID                   0
# TEAM_ABBREVIATION         0
# TEAM_CITY                 0
# PLAYER_ID                 0
# PLAYER_NAME               0
# NICKNAME             615591
# START_POSITION       412863
# COMMENT              558939
# MIN                  109690
# FGM                  109690
# FGA                  109690
# FG_PCT               109690
# FG3M                 109690
# FG3A                 109690
# FG3_PCT              109690
# FTM                  109690
# FTA                  109690
# FT_PCT               109690
# OREB                 109690
# DREB                 109690
# REB                  109690
# AST                  109690
# STL                  109690
# BLK                  109690
# TO                   109690
# PF                   109690
# PTS                  109690
# PLUS_MINUS           133351
# dtype: int64

# %%
games_details.columns
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'PLAYER_ID',
#        'PLAYER_NAME', 'NICKNAME', 'START_POSITION', 'COMMENT', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS',
#        'PLUS_MINUS'],
#       dtype='object')

# %%
start_position_counts = games_details['START_POSITION'].value_counts()
start_position_counts
# Out:
# G    102315
# F    102309
# C     51141
# Name: START_POSITION, dtype: int64

# %%
# Filling null values in the 'START_POSITION' column with 'Other' category
games_details['START_POSITION'].fillna('Other', inplace=True)

# Verifying if the null values are filled
games_details['START_POSITION'].value_counts()
# Out:
# Other    412863
# G        102315
# F        102309
# C         51141
# Name: START_POSITION, dtype: int64

# %%
games_details['PLAYER_NAME'].nunique()
# Out:
# 2664

# %%
grouped_data_2 = games_details.groupby('PLAYER_NAME').agg({
    'START_POSITION':'first'
})

# %%
player_position_dict = grouped_data_2['START_POSITION'].to_dict()
player_position_dict
# Out:
# {'A.J. Guyton': 'Other',
#  'A.J. Lawson': 'Other',
#  'AJ Green': 'Other',
#  'AJ Griffin': 'Other',
#  'AJ Hammons': 'Other',
#  'AJ Price': 'Other',
#  'Aamir Simms': 'Other',
#  'Aaron Brooks': 'G',
#  'Aaron Craft': 'Other',
#  'Aaron Gordon': 'F',
#  'Aaron Gray': 'Other',
#  'Aaron Harrison': 'G',
#  'Aaron Henry': 'Other',
#  'Aaron Holiday': 'Other',
#  'Aaron Jackson': 'Other',
#  'Aaron McKie': 'Other',
#  'Aaron Miles': 'Other',
#  'Aaron Nesmith': 'F',
#  'Aaron Wiggins': 'Other',
#  'Aaron Williams': 'Other',
#  'Abdel Nader': 'Other',
#  'Abdul Gaddy': 'Other',
#  'Acie Law': 'Other',
#  'Adam Chubb': 'Other',
#  'Adam Haluska': 'Other',
#  'Adam Mokoka': 'Other',
#  'Adam Morrison': 'Other',
#  'Adam Parada': 'Other',
#  'Ade Murkey': 'Other',
#  'Ademola Okulaja': 'Other',
#  'Admiral Schofield': 'Other',
#  'Adonal Foyle': 'Other',
#  'Adonis Arms': 'Other',
#  'Adonis Thomas': 'Other',
#  'Adreian Payne': 'Other',
#  'Adrian Griffin': 'Other',
# ...

# %%
games_details['START_POSITION'] = games_details.apply(
    lambda row: player_position_dict[row['PLAYER_NAME']] if pd.isnull(row['START_POSITION']) else row['START_POSITION'],
    axis=1)

# %%
games_details.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  DREB  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0   1.0
# 1   Jeremy Sochan   Jeremy              F     NaN  31:01  ...   6.0   3.0
# 2    Jakob Poeltl    Jakob              C     NaN  21:42  ...   1.0   3.0
# 3   Devin Vassell    Devin              G     NaN  30:20  ...   0.0   9.0
# 4       Tre Jones      Tre              G     NaN  27:44  ...   0.0   2.0
#
#    REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0  2.0  0.0  1.0  0.0  2.0  5.0   2.0        -2.0
# ...

# %%
games_details.head(1)
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  DREB  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0   1.0
#
#    REB  AST  STL  BLK   TO   PF  PTS  PLUS_MINUS
# 0  2.0  0.0  1.0  0.0  2.0  5.0  2.0        -2.0
#
# [1 rows x 29 columns]

# %%
games_details.columns
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'PLAYER_ID',
#        'PLAYER_NAME', 'NICKNAME', 'START_POSITION', 'COMMENT', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS',
#        'PLUS_MINUS'],
#       dtype='object')

# %%
dataset_sort3 = games_details.sort_values(by='PTS',ascending=False)  # Use ascending=False for descending order

# %%
dataset_sort3 = dataset_sort3.dropna(subset=['PTS'])

# %%
dataset_sort3[['GAME_ID','PLAYER_NAME','PTS','MIN','FGM','FGA','FG_PCT']].head(10).to_csv('/content/sample_data/player.csv')

# %%
########
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('/content/games.csv')
data1.head()
# Out:
#    Unnamed: 0        Date   GAME_ID GAMES_STATUS  HOME_TEAM_ID  \
# 0           0  2022-12-22  22200477        Final    1610612740
# 1           1  2022-12-22  22200478        Final    1610612762
# 2           2  2022-12-21  22200466        Final    1610612739
# 3           3  2022-12-21  22200467        Final    1610612755
# 4           4  2022-12-21  22200468        Final    1610612737
#
#    VISITOR_TEAM_ID  SEASON  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0       1610612759    2022     126.0        0.484        0.926         0.382
# 1       1610612764    2022     120.0        0.488        0.952         0.457
# 2       1610612749    2022     114.0        0.482        0.786         0.313
# 3       1610612765    2022     113.0        0.441        0.909         0.297
# 4       1610612741    2022     108.0        0.429        1.000         0.378
#
#    AST_home  REB_home  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26552 entries, 0 to 26551
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       26552 non-null  int64
#  1   Date             26552 non-null  object
#  2   GAME_ID          26552 non-null  int64
#  3   GAMES_STATUS     26552 non-null  object
#  4   HOME_TEAM_ID     26552 non-null  int64
#  5   VISITOR_TEAM_ID  26552 non-null  int64
#  6   SEASON           26552 non-null  int64
#  7   PTS_home         26552 non-null  float64
#  8   FG_PCT_home      26552 non-null  float64
#  9   FT_PCT_home      26552 non-null  float64
#  10  FG3_PCT_home     26552 non-null  float64
#  11  AST_home         26552 non-null  float64
#  12  REB_home         26552 non-null  float64
#  13  PTS_away         26552 non-null  float64
#  14  FG_PCT_away      26552 non-null  float64
#  15  FT_PCT_away      26552 non-null  float64
# ...

# %%
data1['Date'] = pd.to_datetime(data1['Date'])

# %%
data1['GAME_ID'] = data1['GAME_ID'].astype(str)
data1['HOME_TEAM_ID'] = data1['HOME_TEAM_ID'].astype(str)
data1['VISITOR_TEAM_ID'] = data1['VISITOR_TEAM_ID'].astype(str)

# %%
data1['SEASON'] = data1['SEASON'].astype(str)

# %%
home_team= data1[['HOME_TEAM_ID','SEASON','PTS_home','FG_PCT_home','FT_PCT_home','FG3_PCT_home']]

# %%
away_team= data1[['VISITOR_TEAM_ID','SEASON','PTS_away','FG_PCT_away','FT_PCT_away','FG3_PCT_away']]

# %%
home_team.head(2)
# Out:
#   HOME_TEAM_ID SEASON  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home
# 0   1610612740   2022     126.0        0.484        0.926         0.382
# 1   1610612762   2022     120.0        0.488        0.952         0.457

# %%
away_team.head(2)
# Out:
#   VISITOR_TEAM_ID SEASON  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0      1610612759   2022     117.0        0.478        0.815         0.321
# 1      1610612764   2022     112.0        0.561        0.765         0.333

# %%
home_team['HOME_TEAM_ID'].nunique()
# Out:
# 30

# %%
away_team['VISITOR_TEAM_ID'].nunique()
# Out:
# 30

# %%
home_team_grouped = home_team.groupby(['HOME_TEAM_ID']).agg({
    'SEASON':'first',
    'PTS_home': 'mean',
    'FG_PCT_home': 'mean',
    'FT_PCT_home': 'mean',
    'FG3_PCT_home': 'mean'
})

visitor_team_grouped = away_team.groupby(['VISITOR_TEAM_ID']).agg({
    'SEASON':'first',
    'PTS_away': 'mean',
    'FG_PCT_away': 'mean',
    'FT_PCT_away': 'mean',
    'FG3_PCT_away': 'mean'
})

# Resetting index
home_team_grouped = home_team_grouped.reset_index()
visitor_team_grouped = visitor_team_grouped.reset_index()
# Sorting home_team_grouped by PTS_home in descending order
home_team_grouped = home_team_grouped.sort_values(by='PTS_home', ascending=False).head(10)
# Sorting visitor_team_grouped by PTS_away in descending order
visitor_team_grouped = visitor_team_grouped.sort_values(by='PTS_away', ascending=False).head(10)
home_team_grouped = home_team_grouped.reset_index()
visitor_team_grouped = visitor_team_grouped.reset_index()

# %%
home_team_grouped
# Out:
#    index HOME_TEAM_ID SEASON    PTS_home  FG_PCT_home  FT_PCT_home  \
# 0      7   1610612744   2022  109.537611     0.474590     0.767539
# 1      6   1610612743   2022  108.634902     0.470599     0.752627
# 2     19   1610612756   2022  107.706081     0.472912     0.773249
# 3     21   1610612758   2022  105.307049     0.464099     0.765358
# 4     23   1610612760   2022  105.258137     0.463669     0.774749
# 5      5   1610612742   2022  104.956858     0.463106     0.783205
# 6      8   1610612745   2022  104.729911     0.452238     0.748867
# 7     10   1610612747   2022  104.457856     0.460431     0.742245
# 8     24   1610612761   2022  104.147523     0.459671     0.785481
# 9     12   1610612749   2022  104.085227     0.461247     0.755603
#
#    FG3_PCT_home
# 0      0.374571
# 1      0.352187
# 2      0.370601
# 3      0.360559
# 4      0.356364
# 5      0.362954
# 6      0.350980
# 7      0.341751
# 8      0.359061
# 9      0.364081

# %%
visitor_team_grouped
# Out:
#    index VISITOR_TEAM_ID SEASON    PTS_away  FG_PCT_away  FT_PCT_away  \
# 0      7      1610612744   2022  105.496711     0.456484     0.762910
# 1     19      1610612756   2022  105.218430     0.464537     0.770841
# 2      6      1610612743   2022  103.894967     0.458419     0.757393
# 3      8      1610612745   2022  102.864653     0.447596     0.764985
# 4     10      1610612747   2022  102.569620     0.453484     0.743229
# 5     23      1610612760   2022  102.308642     0.447091     0.772786
# 6     13      1610612750   2022  101.867299     0.450799     0.776943
# 7      9      1610612746   2022  101.801370     0.456870     0.754223
# 8     21      1610612758   2022  101.651054     0.448296     0.754350
# 9      5      1610612742   2022  101.331140     0.451871     0.781879
#
#    FG3_PCT_away
# 0      0.365251
# 1      0.356011
# 2      0.346641
# 3      0.354588
# 4      0.345479
# 5      0.338951
# 6      0.345205
# 7      0.358642
# 8      0.351383
# 9      0.351806

# %%
home_team_grouped['HOME_TEAM_ID'] = home_team_grouped['HOME_TEAM_ID'].astype('object')

# %%
home_team_grouped
# Out:
#    index HOME_TEAM_ID SEASON    PTS_home  FG_PCT_home  FT_PCT_home  \
# 0      7   1610612744   2022  109.537611     0.474590     0.767539
# 1      6   1610612743   2022  108.634902     0.470599     0.752627
# 2     19   1610612756   2022  107.706081     0.472912     0.773249
# 3     21   1610612758   2022  105.307049     0.464099     0.765358
# 4     23   1610612760   2022  105.258137     0.463669     0.774749
# 5      5   1610612742   2022  104.956858     0.463106     0.783205
# 6      8   1610612745   2022  104.729911     0.452238     0.748867
# 7     10   1610612747   2022  104.457856     0.460431     0.742245
# 8     24   1610612761   2022  104.147523     0.459671     0.785481
# 9     12   1610612749   2022  104.085227     0.461247     0.755603
#
#    FG3_PCT_home
# 0      0.374571
# 1      0.352187
# 2      0.370601
# 3      0.360559
# 4      0.356364
# 5      0.362954
# 6      0.350980
# 7      0.341751
# 8      0.359061
# 9      0.364081

# %% [markdown]
# # GRAPH 02

# %%
games_data= pd.read_csv('/content/games.csv')

# %%
games_details.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  DREB  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0   1.0
# 1   Jeremy Sochan   Jeremy              F     NaN  31:01  ...   6.0   3.0
# 2    Jakob Poeltl    Jakob              C     NaN  21:42  ...   1.0   3.0
# 3   Devin Vassell    Devin              G     NaN  30:20  ...   0.0   9.0
# 4       Tre Jones      Tre              G     NaN  27:44  ...   0.0   2.0
#
#    REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0  2.0  0.0  1.0  0.0  2.0  5.0   2.0        -2.0
# ...

# %%
players=games_details['PLAYER_NAME']
no_of_games_played = players.value_counts().to_frame().reset_index()

# %%
no_of_games_played.rename(columns={'Player_Name': 'PLAYER_NAME','PLAYER_NAME': 'Count'},inplace = True)

# %%
top_10_players= no_of_games_played.head(10)
top_10_players
# Out:
#        PLAYER_NAME  Count
# 0     LeBron James   1795
# 1    Udonis Haslem   1720
# 2   Andre Iguodala   1560
# 3    Dwight Howard   1541
# 4      Kyle Korver   1534
# 5       Chris Paul   1520
# 6  Carmelo Anthony   1518
# 7     Vince Carter   1470
# 8     Trevor Ariza   1451
# 9      Tony Parker   1420

# %%
grouped_data = games_details.groupby('PLAYER_NAME').agg({'PTS': 'sum'})

# %%
grouped_data.reset_index(inplace=True)

# %%
grouped_data.sort_values(by='PTS',ascending=False,inplace=True)

# %%
top_10_players_with_highest_score=grouped_data.head(10)
top_10_players_with_highest_score.reset_index(inplace=True)

# %%
top_10_players_with_highest_score
# Out:
#    index        PLAYER_NAME      PTS
# 0   1593       LeBron James  46638.0
# 1   1489       Kevin Durant  32327.0
# 2    345    Carmelo Anthony  31658.0
# 3   1095       James Harden  28460.0
# 4    753        Dwyane Wade  28102.0
# 5    705      Dirk Nowitzki  27927.0
# 6   1526        Kobe Bryant  27287.0
# 7   2207  Russell Westbrook  27180.0
# 8   2340      Stephen Curry  25826.0
# 9    416         Chris Paul  25086.0

# %%
import matplotlib.pyplot as plt

# Assuming you have already defined 'top_10_players' and 'top_10_players_with_highest_score' DataFrames

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Identify common player names between the two DataFrames
common_players = set(top_10_players['PLAYER_NAME']).intersection(top_10_players_with_highest_score['PLAYER_NAME'])

# Create a color list where common players have the same color and others are gray
colors1 = ['skyblue' if player in common_players else 'lightgray' for player in top_10_players['PLAYER_NAME']]
colors2 = ['skyblue' if player in common_players else 'lightgray' for player in top_10_players_with_highest_score['PLAYER_NAME']]

# First subplot for 'Games Played'
ax1.bar(top_10_players['PLAYER_NAME'], top_10_players['Count'], color=colors1)
ax1.set_ylabel('Games Played', fontsize=12)
ax1.set_xlabel('Player Name', fontsize=12)
ax1.set_title('Top 10 Players by Games Played', fontsize=14)
ax1.tick_params(axis='x', rotation=90)  # Rotate x-axis labels by 90 degrees

# Add data labels above the bars for the first subplot
for index, value in enumerate(top_10_players['Count']):
    ax1.text(index, value, str(value), ha='center', va='bottom', fontsize=10)

# Second subplot for 'Total Points Score'
ax2.bar(top_10_players_with_highest_score['PLAYER_NAME'], top_10_players_with_highest_score['PTS'], color=colors2)
ax2.set_ylabel('Total Points Score', fontsize=12)
ax2.set_xlabel('Player Name', fontsize=12)
ax2.set_title('Top 10 Players With Highest Point', fontsize=14)
ax2.tick_params(axis='x', rotation=90)  # Rotate x-axis labels by 90 degrees

# Add data labels above the bars for the second subplot
for index, value in enumerate(top_10_players_with_highest_score['PTS']):
    value_in_k = value / 1000  # Convert to K format
    ax2.text(index, value, f'{value_in_k:.2f}k', ha='center', va='bottom', fontsize=10)

# Customize the appearance of the grid lines (optional)

# Remove the top and right spines for both subplots (optional)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

# Ensure proper spacing
plt.tight_layout()

# Display the subplots
plt.show()

# %% [markdown]
# # Graph 03

# %%
grouped_data = games.groupby('SEASON').agg({
    'HOME_TEAM_WINS': 'sum',
    'SEASON': 'count'  # Count the number of rows (matches) for each season
})

# Rename the columns for clarity (optional)
grouped_data.rename(columns={'HOME_TEAM_WINS': 'TOTAL_HOME_TEAM_WINS', 'SEASON': 'TOTAL_MATCHES'}, inplace=True)

# Display the result
print(grouped_data)
# Out:
#         TOTAL_HOME_TEAM_WINS  TOTAL_MATCHES
# SEASON
# 2003                     800           1286
# 2004                     824           1362
# 2005                     866           1432
# 2006                     839           1419
# 2007                     862           1411
# 2008                     857           1425
# 2009                     857           1424
# 2010                     871           1422
# 2011                     656           1104
# 2012                     872           1420
# 2013                     819           1427
# 2014                     816           1418
# 2015                     841           1416
# 2016                     816           1405
# 2017                     805           1382
# 2018                     810           1378
# 2019                     666           1241
# 2020                     681           1249
# 2021                     768           1389
# 2022                     319            542

# %%
grouped_data['PERCENTAGE_HOME_TEAM_WINS'] = round((grouped_data['TOTAL_HOME_TEAM_WINS'] / grouped_data['TOTAL_MATCHES']) * 100, 2)
grouped_data['PERCENTAGE_AWAY_TEAM_WINS'] = round((grouped_data['TOTAL_AWAY_TEAM_WINS'] / grouped_data['TOTAL_MATCHES']) * 100, 2)
# Out:
# <ipython-input-115-a5968e9134ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_data['PERCENTAGE_HOME_TEAM_WINS'] = round((grouped_data['TOTAL_HOME_TEAM_WINS'] / grouped_data['TOTAL_MATCHES']) * 100, 2)

# %%
grouped_data['TOTAL_AWAY_TEAM_WINS']= grouped_data['TOTAL_MATCHES']  - grouped_data['TOTAL_HOME_TEAM_WINS']
grouped_data = grouped_data[['TOTAL_HOME_TEAM_WINS', 'PERCENTAGE_HOME_TEAM_WINS', 'TOTAL_AWAY_TEAM_WINS', 'PERCENTAGE_AWAY_TEAM_WINS','TOTAL_MATCHES']]
grouped_data.reset_index(inplace=True)

# %%
grouped_data.columns
# Out:
# Index(['SEASON', 'TOTAL_HOME_TEAM_WINS', 'PERCENTAGE_HOME_TEAM_WINS',
#        'TOTAL_AWAY_TEAM_WINS', 'PERCENTAGE_AWAY_TEAM_WINS', 'TOTAL_MATCHES'],
#       dtype='object')

# %%
# Extracting the percentage of wins and the seasons
home_team_wins = grouped_data['PERCENTAGE_HOME_TEAM_WINS'].values
away_team_wins = grouped_data['PERCENTAGE_AWAY_TEAM_WINS'].values
seasons = grouped_data['SEASON'].astype(str).values  # Convert season numbers to strings for labeling purposes

# Generate y positions for each season
y_pos = np.arange(len(seasons))


# Increase the bar width
bar_width = 0.6

# Define shades of blue for the home and away team bars
color_home = 'lightblue'  # A darker shade for the home team
color_away = 'skyblue'  # A lighter shade for the away team

# Create the figure and axis objects again with the new bar width and colors
fig, ax = plt.subplots(figsize=(14, 8))

# Plot the bars for home team wins and away team wins in opposite directions with new colors
bars_home = ax.barh(y_pos, home_team_wins, height=bar_width, color=color_home, label='Home Team Wins')
bars_away = ax.barh(y_pos, -away_team_wins, height=bar_width, color=color_away, label='Away Team Wins')

# Add the season labels on the y-axis
ax.set_yticks(y_pos)
ax.set_yticklabels(seasons)
ax.invert_yaxis()  # Labels read top-to-bottom

# Adding data labels on the bars
for bar in bars_home:
    width = bar.get_width()
    ax.text(width, bar.get_y() + bar.get_height() / 2, f'{width}%', ha='right', va='center')

for bar in bars_away:
    width = bar.get_width()
    ax.text(width, bar.get_y() + bar.get_height() / 2, f'{-width}%', ha='left', va='center')

# Set labels, title and legend
ax.set_xlabel('Percentage')
ax.set_title('Home and Away Team Wins Percentage by Season')
ax.legend(loc='upper right', bbox_to_anchor=(1.15, 1))

# Removing the spines and setting grid
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Display horizontal grid lines
ax.xaxis.grid(True)
ax.yaxis.grid(False)

# Set the x-axis limits to the specified range
ax.set_xlim(-50, 70)

#Remove x-axis ticks
ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Remove grid lines
ax.grid(False)

# Remove grid lines
ax.grid(False)



# Show the plot with the new adjustments
plt.tight_layout()
plt.show()
